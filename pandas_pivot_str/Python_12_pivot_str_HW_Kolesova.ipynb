# %%
import pandas as pd

# %%
#как-то очень тупо вышло, понимаю, но иначе не придумала
#also, не смогла с помощью скобок перенестии длинные строки. =/
log = pd.read_csv('visit_log.csv', sep = ';')
log.loc[((log.traffic_source == 'yandex') | (log.traffic_source == 'google')), 'source_type'] = 'organic'
log.loc[((log.traffic_source == 'email') | (log.traffic_source == 'paid')) & (log.region == 'Russia'), 'source_type'] = 'ad'
log.loc[((log.traffic_source == 'email') | (log.traffic_source == 'paid')) & ~(log.region == 'Russia'), 'source_type'] = 'other'
log.tail(20)
# Out:
#         timestamp    visit_id                                 url     region  \
# 18918  1550094214  cb9ab50478  https://host.ru/f1eb4601740d627ab0      China
# 18919  1550094214  6da87e20bd  https://host.ru/39fa884393666d45fc      China
# 18920  1550094217  3d4349ecf8  https://host.ru/9f90e5c423a5f976d4    Ukraine
# 18921  1550094218  b9723ef95e  https://host.ru/c8d9213a31839f9a3a    Ukraine
# 18922  1550094219  61267237e5  https://host.ru/f2297425e1328e9e35     Russia
# 18923  1550094221  42af1bbaa1  https://host.ru/6fda01ec57f23abc9e     Russia
# 18924  1550094227  ea2af937ec  https://host.ru/c8d9213a31839f9a3a     Russia
# 18925  1550094228  90efa16935  https://host.ru/23c64743ad842b9311    Belarus
# 18926  1550094236  098c3666b2  https://host.ru/b8b58337d272ee7b15    Ukraine
# 18927  1550094245  1e0d086733  https://host.ru/c2382eb3d6afc8d0f3    Ukraine
# 18928  1550094255  c7e4bce62a  https://host.ru/8880fd00cf23066541  Australia
# ...

# %%
urls = pd.read_csv('URLs.txt')
urls[urls.url.str.contains(pat = '/[0-9]{8}-')].head(10)
# Out:
#                                                   url
# 3   /politics/36188461-s-marta-zhizn-rossiyan-susc...
# 4   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# 5   /science/36157853-nasa-sobiraet-ekstrennuyu-pr...
# 6   /video/36001498-poyavilis-pervye-podrobnosti-g...
# 7   /world/36007585-tramp-pridumal-kak-reshit-ukra...
# 10  /middleeast/36131117-divizion-s-400-ne-zametil...
# 11  /economics/36065674-rossiyane-vozmutilis-minim...
# 12  /politics/36118047-otets-24-detey-potreboval-i...
# 13  /travel/36194479-v-sheremetevo-passazhiry-ustr...
# 14  /politics/35638742-nesolidno-mariya-zaharova-s...

# %%
data = pd.DataFrame({
    'keyword': ['курс гривны к рублю', 'доллары в рубли', '100 долларов в рублях', 'курс рубля'],
    'shows': [125076, 114173, 97534, 53546],
})

# %%
from pymystem3 import Mystem
m = Mystem()
data['lemmas'] = data['keyword'].apply(lambda phrase: ' '.join(m.lemmatize(str(phrase))))
data
# Out:
#                  keyword   shows                        lemmas
# 0    курс гривны к рублю  125076  курс   гривна   к   рубль \n
# 1        доллары в рубли  114173         доллар   в   рубль \n
# 2  100 долларов в рублях   97534   100   доллар   в   рубль \n
# 3             курс рубля   53546               курс   рубль \n
